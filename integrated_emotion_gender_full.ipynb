# %% [markdown]
# # Integrated Emotion and Gender Classification

# %% [markdown]
# This notebook combines the Emotion and Gender classification models into a single workflow. It includes all functions, parameters, debugging code, and testing from both models. At the end, the models will be exported for use in other applications.

# %% [markdown]
# ## Emotion Classification Model

# %% [markdown]
# # Emotion Classification Model - IPYNB
#
# pip install numpy tensorflow scikit-learn matplotlib

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras import layers, models, regularizers
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %%
# Define parameters
IMG_SIZE = (48, 48)
BATCH_SIZE = 32
VALIDATION_SPLIT = 0.2
l2_strength = 0.001  # L2 regularization strength

# %% [markdown]
# - Modify this based on the path of the training & testing dataset

# %%
# Directories
train_dir = 'C:/Users/Melvin Tang/OneDrive/Codes/I2ML/FINALPRO/archive/train'

test_dirs = [
    'C:/Users/Melvin Tang/OneDrive/Codes/I2ML/FINALPRO/archive/testgeli',
    'C:/Users/Melvin Tang/OneDrive/Codes/I2ML/FINALPRO/archive/testkevin',
    'C:/Users/Melvin Tang/OneDrive/Codes/I2ML/FINALPRO/archive/test'
]

# %%
# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=17,
    horizontal_flip=True, 
    validation_split=VALIDATION_SPLIT,
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    color_mode='rgb',  # Keeping RGB as in your original code
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 20011 images belonging to 5 classes.
# Found 5000 images belonging to 5 classes.

# %%
# Categories for the classes
categories = list(train_generator.class_indices.keys())

# Compute Class Weights
labels = train_generator.classes
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(labels), y=labels)
class_weights_dict = dict(enumerate(class_weights))

# %%
# Model Definition
model = models.Sequential([
    # First Convolutional Block
    layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal',
                  kernel_regularizer=regularizers.l2(l2_strength), input_shape=(48, 48, 3)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal',
                  kernel_regularizer=regularizers.l2(l2_strength)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),  # Reduced dropout rate

    # Second Convolutional Block
    layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_normal',
                  kernel_regularizer=regularizers.l2(l2_strength)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Conv2D(128, (3, 3), padding='same', kernel_initializer='he_normal',
                  kernel_regularizer=regularizers.l2(l2_strength)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.3),  # Reduced dropout rate

    # Third Convolutional Block
    layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_normal',
                  kernel_regularizer=regularizers.l2(l2_strength)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Conv2D(256, (3, 3), padding='same', kernel_initializer='he_normal',
                  kernel_regularizer=regularizers.l2(l2_strength)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),  # Reduced dropout rate

    # Fourth Convolutional Block (Added)
    layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_normal',
                  kernel_regularizer=regularizers.l2(l2_strength)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Conv2D(512, (3, 3), padding='same', kernel_initializer='he_normal',
                  kernel_regularizer=regularizers.l2(l2_strength)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.5),  # Maintained dropout rate

    # Fully Connected Layers
    layers.Flatten(),
    layers.Dense(512, kernel_initializer='he_normal',
                 kernel_regularizer=regularizers.l2(l2_strength)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Dropout(0.5),  # Reduced dropout rate
    layers.Dense(5, activation='softmax')
])

# %% [markdown]
# - Model Compiling, Loss Functions and Callbacks
# (Utilized early stopping and learning rate reducer)

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0005)  # Reduced learning rate

# Using label smoothing
loss_function = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)

model.compile(optimizer=optimizer,
              loss=loss_function,
              metrics=['accuracy'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=100,
    validation_data=validation_generator,
    class_weight=class_weights_dict,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/100
# 626/626 [==============================] - 61s 62ms/step - loss: 20.8479 - accuracy: 0.2245 - val_loss: 4.6944 - val_accuracy: 0.2882 - lr: 5.0000e-04
# Epoch 2/100
# 626/626 [==============================] - 34s 54ms/step - loss: 3.1984 - accuracy: 0.2535 - val_loss: 2.3906 - val_accuracy: 0.1992 - lr: 5.0000e-04
# Epoch 3/100
# 626/626 [==============================] - 34s 54ms/step - loss: 2.3144 - accuracy: 0.3082 - val_loss: 2.2151 - val_accuracy: 0.2860 - lr: 5.0000e-04
# Epoch 4/100
# 626/626 [==============================] - 34s 54ms/step - loss: 2.0816 - accuracy: 0.3132 - val_loss: 1.9553 - val_accuracy: 0.3222 - lr: 5.0000e-04
# Epoch 5/100
# 626/626 [==============================] - 34s 55ms/step - loss: 1.9073 - accuracy: 0.3528 - val_loss: 1.8450 - val_accuracy: 0.3712 - lr: 5.0000e-04
# Epoch 6/100
# 626/626 [==============================] - 34s 54ms/step - loss: 1.8807 - accuracy: 0.3545 - val_loss: 1.9132 - val_accuracy: 0.3296 - lr: 5.0000e-04
# Epoch 7/100
# 626/626 [==============================] - 34s 54ms/step - loss: 1.8584 - accuracy: 0.3577 - val_loss: 2.0072 - val_accuracy: 0.2322 - lr: 5.0000e-04
# Epoch 8/100
# 626/626 [==============================] - 39s 62ms/step - loss: 1.8681 - accuracy: 0.3571 - val_loss: 2.0596 - val_accuracy: 0.2066 - lr: 5.0000e-04
# Epoch 9/100
# 626/626 [==============================] - 52s 83ms/step - loss: 1.8829 - accuracy: 0.3604 - val_loss: 1.9432 - val_accuracy: 0.2588 - lr: 5.0000e-04
# Epoch 10/100
# 626/626 [==============================] - 42s 68ms/step - loss: 1.8810 - accuracy: 0.3660 - val_loss: 2.3444 - val_accuracy: 0.3186 - lr: 5.0000e-04
# Epoch 11/100
# 626/626 [==============================] - 39s 63ms/step - loss: 1.7179 - accuracy: 0.3897 - val_loss: 1.6707 - val_accuracy: 0.3516 - lr: 2.5000e-04
# Epoch 12/100
# 626/626 [==============================] - 39s 62ms/step - loss: 1.7104 - accuracy: 0.3969 - val_loss: 1.8223 - val_accuracy: 0.2920 - lr: 2.5000e-04
# Epoch 13/100
# 626/626 [==============================] - 36s 58ms/step - loss: 1.6987 - accuracy: 0.3935 - val_loss: 1.6494 - val_accuracy: 0.3916 - lr: 2.5000e-04
# Epoch 14/100
# 626/626 [==============================] - 40s 63ms/step - loss: 1.6959 - accuracy: 0.4055 - val_loss: 1.6432 - val_accuracy: 0.4184 - lr: 2.5000e-04
# Epoch 15/100
# 626/626 [==============================] - 35s 55ms/step - loss: 1.6962 - accuracy: 0.4084 - val_loss: 1.6663 - val_accuracy: 0.3690 - lr: 2.5000e-04
# Epoch 16/100
# 626/626 [==============================] - 35s 56ms/step - loss: 1.6920 - accuracy: 0.4072 - val_loss: 1.6627 - val_accuracy: 0.4112 - lr: 2.5000e-04
# Epoch 17/100
# 626/626 [==============================] - 35s 56ms/step - loss: 1.6782 - accuracy: 0.4052 - val_loss: 1.7381 - val_accuracy: 0.3474 - lr: 2.5000e-04
# Epoch 18/100
# 626/626 [==============================] - 34s 55ms/step - loss: 1.6721 - accuracy: 0.4100 - val_loss: 1.6407 - val_accuracy: 0.4108 - lr: 2.5000e-04
# Epoch 19/100
# 626/626 [==============================] - 34s 54ms/step - loss: 1.6847 - accuracy: 0.4156 - val_loss: 1.9211 - val_accuracy: 0.2612 - lr: 2.5000e-04
# Epoch 20/100
# 626/626 [==============================] - 34s 54ms/step - loss: 1.6893 - accuracy: 0.4222 - val_loss: 1.8468 - val_accuracy: 0.3226 - lr: 2.5000e-04
# Epoch 21/100
# 626/626 [==============================] - 37s 58ms/step - loss: 1.7064 - accuracy: 0.4257 - val_loss: 1.7116 - val_accuracy: 0.4332 - lr: 2.5000e-04
# Epoch 22/100
# 626/626 [==============================] - 34s 54ms/step - loss: 1.7335 - accuracy: 0.4483 - val_loss: 1.8226 - val_accuracy: 0.3740 - lr: 2.5000e-04
# Epoch 23/100
# 626/626 [==============================] - 34s 54ms/step - loss: 1.7143 - accuracy: 0.4612 - val_loss: 1.6577 - val_accuracy: 0.4576 - lr: 2.5000e-04
# Epoch 24/100
# 626/626 [==============================] - 38s 60ms/step - loss: 1.5914 - accuracy: 0.4873 - val_loss: 1.5710 - val_accuracy: 0.4558 - lr: 1.2500e-04
# Epoch 25/100
# 626/626 [==============================] - 40s 64ms/step - loss: 1.5564 - accuracy: 0.5017 - val_loss: 1.5611 - val_accuracy: 0.4618 - lr: 1.2500e-04
# Epoch 26/100
# 626/626 [==============================] - 36s 57ms/step - loss: 1.5521 - accuracy: 0.5091 - val_loss: 1.5035 - val_accuracy: 0.5158 - lr: 1.2500e-04
# Epoch 27/100
# 626/626 [==============================] - 45s 72ms/step - loss: 1.5422 - accuracy: 0.5202 - val_loss: 1.6910 - val_accuracy: 0.4446 - lr: 1.2500e-04
# Epoch 28/100
# 626/626 [==============================] - 39s 62ms/step - loss: 1.5278 - accuracy: 0.5272 - val_loss: 1.5662 - val_accuracy: 0.4660 - lr: 1.2500e-04
# Epoch 29/100
# 626/626 [==============================] - 39s 62ms/step - loss: 1.5244 - accuracy: 0.5315 - val_loss: 1.4867 - val_accuracy: 0.5238 - lr: 1.2500e-04
# Epoch 30/100
# 626/626 [==============================] - 35s 56ms/step - loss: 1.5223 - accuracy: 0.5313 - val_loss: 1.4810 - val_accuracy: 0.5280 - lr: 1.2500e-04
# Epoch 31/100
# 626/626 [==============================] - 28s 45ms/step - loss: 1.5146 - accuracy: 0.5387 - val_loss: 1.4769 - val_accuracy: 0.5234 - lr: 1.2500e-04
# Epoch 32/100
# 626/626 [==============================] - 28s 45ms/step - loss: 1.5103 - accuracy: 0.5477 - val_loss: 1.6554 - val_accuracy: 0.4404 - lr: 1.2500e-04
# Epoch 33/100
# 626/626 [==============================] - 36s 58ms/step - loss: 1.5055 - accuracy: 0.5483 - val_loss: 1.7960 - val_accuracy: 0.4222 - lr: 1.2500e-04
# Epoch 34/100
# 626/626 [==============================] - 28s 45ms/step - loss: 1.4964 - accuracy: 0.5609 - val_loss: 1.5502 - val_accuracy: 0.4848 - lr: 1.2500e-04
# Epoch 35/100
# 626/626 [==============================] - 28s 45ms/step - loss: 1.4977 - accuracy: 0.5580 - val_loss: 1.4211 - val_accuracy: 0.5848 - lr: 1.2500e-04
# Epoch 36/100
# 626/626 [==============================] - 28s 45ms/step - loss: 1.4925 - accuracy: 0.5665 - val_loss: 1.8702 - val_accuracy: 0.3354 - lr: 1.2500e-04
# Epoch 37/100
# 626/626 [==============================] - 28s 45ms/step - loss: 1.4821 - accuracy: 0.5689 - val_loss: 1.4723 - val_accuracy: 0.5566 - lr: 1.2500e-04
# Epoch 38/100
# 626/626 [==============================] - 28s 45ms/step - loss: 1.4873 - accuracy: 0.5645 - val_loss: 1.4583 - val_accuracy: 0.5652 - lr: 1.2500e-04
# Epoch 39/100
# 626/626 [==============================] - 29s 46ms/step - loss: 1.4857 - accuracy: 0.5732 - val_loss: 1.5376 - val_accuracy: 0.5096 - lr: 1.2500e-04
# Epoch 40/100
# 626/626 [==============================] - 29s 46ms/step - loss: 1.4831 - accuracy: 0.5759 - val_loss: 1.4419 - val_accuracy: 0.5690 - lr: 1.2500e-04
# Epoch 41/100
# 626/626 [==============================] - 29s 46ms/step - loss: 1.4052 - accuracy: 0.5978 - val_loss: 1.3525 - val_accuracy: 0.5952 - lr: 6.2500e-05
# Epoch 42/100
# 626/626 [==============================] - 29s 46ms/step - loss: 1.3748 - accuracy: 0.6016 - val_loss: 1.3518 - val_accuracy: 0.5912 - lr: 6.2500e-05
# Epoch 43/100
# 626/626 [==============================] - 29s 45ms/step - loss: 1.3649 - accuracy: 0.6091 - val_loss: 1.3215 - val_accuracy: 0.6040 - lr: 6.2500e-05
# Epoch 44/100
# 626/626 [==============================] - 28s 45ms/step - loss: 1.3543 - accuracy: 0.6125 - val_loss: 1.3458 - val_accuracy: 0.5872 - lr: 6.2500e-05
# Epoch 45/100
# 626/626 [==============================] - 29s 46ms/step - loss: 1.3418 - accuracy: 0.6192 - val_loss: 1.4014 - val_accuracy: 0.5560 - lr: 6.2500e-05
# Epoch 46/100
# 626/626 [==============================] - 28s 45ms/step - loss: 1.3401 - accuracy: 0.6183 - val_loss: 1.3019 - val_accuracy: 0.6104 - lr: 6.2500e-05
# Epoch 47/100
# 626/626 [==============================] - 28s 45ms/step - loss: 1.3383 - accuracy: 0.6216 - val_loss: 1.4757 - val_accuracy: 0.5424 - lr: 6.2500e-05
# Epoch 48/100
# 626/626 [==============================] - 28s 45ms/step - loss: 1.3309 - accuracy: 0.6261 - val_loss: 1.3889 - val_accuracy: 0.5848 - lr: 6.2500e-05
# Epoch 49/100
# 626/626 [==============================] - 27s 44ms/step - loss: 1.3297 - accuracy: 0.6237 - val_loss: 1.3035 - val_accuracy: 0.6116 - lr: 6.2500e-05
# Epoch 50/100
# 626/626 [==============================] - 27s 44ms/step - loss: 1.3261 - accuracy: 0.6218 - val_loss: 1.3409 - val_accuracy: 0.5874 - lr: 6.2500e-05
# Epoch 51/100
# 626/626 [==============================] - 28s 44ms/step - loss: 1.3253 - accuracy: 0.6279 - val_loss: 1.3863 - val_accuracy: 0.5658 - lr: 6.2500e-05
# Epoch 52/100
# 626/626 [==============================] - 31s 49ms/step - loss: 1.2780 - accuracy: 0.6473 - val_loss: 1.2354 - val_accuracy: 0.6350 - lr: 3.1250e-05
# Epoch 53/100
# 626/626 [==============================] - 44s 69ms/step - loss: 1.2538 - accuracy: 0.6520 - val_loss: 1.2459 - val_accuracy: 0.6196 - lr: 3.1250e-05
# Epoch 54/100
# 626/626 [==============================] - 51s 81ms/step - loss: 1.2432 - accuracy: 0.6559 - val_loss: 1.2363 - val_accuracy: 0.6320 - lr: 3.1250e-05
# Epoch 55/100
# 626/626 [==============================] - 52s 84ms/step - loss: 1.2392 - accuracy: 0.6570 - val_loss: 1.2291 - val_accuracy: 0.6276 - lr: 3.1250e-05
# Epoch 56/100
# 626/626 [==============================] - 53s 85ms/step - loss: 1.2327 - accuracy: 0.6558 - val_loss: 1.2295 - val_accuracy: 0.6310 - lr: 3.1250e-05
# Epoch 57/100
# 626/626 [==============================] - 54s 87ms/step - loss: 1.2271 - accuracy: 0.6580 - val_loss: 1.2185 - val_accuracy: 0.6310 - lr: 3.1250e-05
# Epoch 58/100
# 626/626 [==============================] - 53s 85ms/step - loss: 1.2213 - accuracy: 0.6655 - val_loss: 1.2293 - val_accuracy: 0.6354 - lr: 3.1250e-05
# Epoch 59/100
# 626/626 [==============================] - 53s 84ms/step - loss: 1.2158 - accuracy: 0.6695 - val_loss: 1.2431 - val_accuracy: 0.6284 - lr: 3.1250e-05
# Epoch 60/100
# 626/626 [==============================] - 53s 84ms/step - loss: 1.2192 - accuracy: 0.6666 - val_loss: 1.2159 - val_accuracy: 0.6414 - lr: 3.1250e-05
# Epoch 61/100
# 626/626 [==============================] - 53s 84ms/step - loss: 1.2117 - accuracy: 0.6671 - val_loss: 1.2235 - val_accuracy: 0.6304 - lr: 3.1250e-05
# Epoch 62/100
# 626/626 [==============================] - 52s 84ms/step - loss: 1.2040 - accuracy: 0.6731 - val_loss: 1.2160 - val_accuracy: 0.6438 - lr: 3.1250e-05
# Epoch 63/100
# 626/626 [==============================] - 52s 84ms/step - loss: 1.2077 - accuracy: 0.6750 - val_loss: 1.2223 - val_accuracy: 0.6344 - lr: 3.1250e-05
# Epoch 64/100
# 626/626 [==============================] - 53s 84ms/step - loss: 1.2007 - accuracy: 0.6752 - val_loss: 1.2259 - val_accuracy: 0.6314 - lr: 3.1250e-05
# Epoch 65/100
# 626/626 [==============================] - 53s 84ms/step - loss: 1.2004 - accuracy: 0.6764 - val_loss: 1.2228 - val_accuracy: 0.6336 - lr: 3.1250e-05
# Epoch 66/100
# 626/626 [==============================] - 53s 84ms/step - loss: 1.1715 - accuracy: 0.6910 - val_loss: 1.1929 - val_accuracy: 0.6488 - lr: 1.5625e-05
# Epoch 67/100
# 626/626 [==============================] - 53s 84ms/step - loss: 1.1552 - accuracy: 0.6953 - val_loss: 1.1995 - val_accuracy: 0.6466 - lr: 1.5625e-05
# Epoch 68/100
# 626/626 [==============================] - 51s 81ms/step - loss: 1.1456 - accuracy: 0.6989 - val_loss: 1.1796 - val_accuracy: 0.6510 - lr: 1.5625e-05
# Epoch 69/100
# 626/626 [==============================] - 51s 81ms/step - loss: 1.1408 - accuracy: 0.7011 - val_loss: 1.1883 - val_accuracy: 0.6556 - lr: 1.5625e-05
# Epoch 70/100
# 626/626 [==============================] - 51s 82ms/step - loss: 1.1316 - accuracy: 0.7039 - val_loss: 1.1826 - val_accuracy: 0.6522 - lr: 1.5625e-05
# Epoch 71/100
# 626/626 [==============================] - 52s 83ms/step - loss: 1.1345 - accuracy: 0.7004 - val_loss: 1.1718 - val_accuracy: 0.6536 - lr: 1.5625e-05
# Epoch 72/100
# 626/626 [==============================] - 52s 82ms/step - loss: 1.1249 - accuracy: 0.7064 - val_loss: 1.1991 - val_accuracy: 0.6446 - lr: 1.5625e-05
# Epoch 73/100
# 626/626 [==============================] - 52s 83ms/step - loss: 1.1228 - accuracy: 0.7077 - val_loss: 1.1787 - val_accuracy: 0.6528 - lr: 1.5625e-05
# Epoch 74/100
# 626/626 [==============================] - 51s 82ms/step - loss: 1.1177 - accuracy: 0.7108 - val_loss: 1.1750 - val_accuracy: 0.6534 - lr: 1.5625e-05
# Epoch 75/100
# 626/626 [==============================] - 53s 84ms/step - loss: 1.1125 - accuracy: 0.7132 - val_loss: 1.1712 - val_accuracy: 0.6562 - lr: 1.5625e-05
# Epoch 76/100
# 626/626 [==============================] - 53s 85ms/step - loss: 1.1138 - accuracy: 0.7097 - val_loss: 1.1739 - val_accuracy: 0.6536 - lr: 1.5625e-05
# Epoch 77/100
# 626/626 [==============================] - 53s 84ms/step - loss: 1.1116 - accuracy: 0.7137 - val_loss: 1.1695 - val_accuracy: 0.6576 - lr: 1.5625e-05
# Epoch 78/100
# 626/626 [==============================] - 52s 84ms/step - loss: 1.1032 - accuracy: 0.7189 - val_loss: 1.1681 - val_accuracy: 0.6590 - lr: 1.5625e-05
# Epoch 79/100
# 626/626 [==============================] - 53s 84ms/step - loss: 1.1011 - accuracy: 0.7219 - val_loss: 1.1694 - val_accuracy: 0.6570 - lr: 1.5625e-05
# Epoch 80/100
# 626/626 [==============================] - 52s 83ms/step - loss: 1.0979 - accuracy: 0.7176 - val_loss: 1.1875 - val_accuracy: 0.6488 - lr: 1.5625e-05
# Epoch 81/100
# 626/626 [==============================] - 53s 84ms/step - loss: 1.0977 - accuracy: 0.7213 - val_loss: 1.1973 - val_accuracy: 0.6426 - lr: 1.5625e-05
# Epoch 82/100
# 626/626 [==============================] - 52s 84ms/step - loss: 1.0964 - accuracy: 0.7206 - val_loss: 1.1924 - val_accuracy: 0.6560 - lr: 1.5625e-05
# Epoch 83/100
# 626/626 [==============================] - 53s 84ms/step - loss: 1.0942 - accuracy: 0.7223 - val_loss: 1.1804 - val_accuracy: 0.6564 - lr: 1.5625e-05
# Epoch 84/100
# 626/626 [==============================] - 53s 84ms/step - loss: 1.0788 - accuracy: 0.7335 - val_loss: 1.1621 - val_accuracy: 0.6646 - lr: 7.8125e-06
# Epoch 85/100
# 626/626 [==============================] - 53s 84ms/step - loss: 1.0647 - accuracy: 0.7352 - val_loss: 1.1582 - val_accuracy: 0.6676 - lr: 7.8125e-06
# Epoch 86/100
# 626/626 [==============================] - 53s 84ms/step - loss: 1.0603 - accuracy: 0.7401 - val_loss: 1.1590 - val_accuracy: 0.6678 - lr: 7.8125e-06
# Epoch 87/100
# 626/626 [==============================] - 53s 84ms/step - loss: 1.0568 - accuracy: 0.7415 - val_loss: 1.1685 - val_accuracy: 0.6650 - lr: 7.8125e-06
# Epoch 88/100
# 626/626 [==============================] - 56s 89ms/step - loss: 1.0532 - accuracy: 0.7418 - val_loss: 1.1559 - val_accuracy: 0.6722 - lr: 7.8125e-06
# Epoch 89/100
# 626/626 [==============================] - 58s 92ms/step - loss: 1.0511 - accuracy: 0.7428 - val_loss: 1.1604 - val_accuracy: 0.6652 - lr: 7.8125e-06
# Epoch 90/100
# 626/626 [==============================] - 50s 79ms/step - loss: 1.0500 - accuracy: 0.7408 - val_loss: 1.1738 - val_accuracy: 0.6552 - lr: 7.8125e-06
# Epoch 91/100
# 626/626 [==============================] - 49s 79ms/step - loss: 1.0366 - accuracy: 0.7478 - val_loss: 1.1659 - val_accuracy: 0.6650 - lr: 7.8125e-06
# Epoch 92/100
# 626/626 [==============================] - 49s 78ms/step - loss: 1.0433 - accuracy: 0.7445 - val_loss: 1.1666 - val_accuracy: 0.6642 - lr: 7.8125e-06
# Epoch 93/100
# 626/626 [==============================] - 50s 79ms/step - loss: 1.0347 - accuracy: 0.7470 - val_loss: 1.1667 - val_accuracy: 0.6652 - lr: 7.8125e-06
# Epoch 94/100
# 626/626 [==============================] - 50s 80ms/step - loss: 1.0201 - accuracy: 0.7538 - val_loss: 1.1506 - val_accuracy: 0.6696 - lr: 3.9063e-06
# Epoch 95/100
# 626/626 [==============================] - 50s 80ms/step - loss: 1.0137 - accuracy: 0.7585 - val_loss: 1.1561 - val_accuracy: 0.6716 - lr: 3.9063e-06
# Epoch 96/100
# 626/626 [==============================] - 50s 79ms/step - loss: 1.0075 - accuracy: 0.7616 - val_loss: 1.1504 - val_accuracy: 0.6700 - lr: 3.9063e-06
# Epoch 97/100
# 626/626 [==============================] - 49s 78ms/step - loss: 1.0130 - accuracy: 0.7600 - val_loss: 1.1568 - val_accuracy: 0.6696 - lr: 3.9063e-06
# Epoch 98/100
# 626/626 [==============================] - 50s 79ms/step - loss: 1.0066 - accuracy: 0.7574 - val_loss: 1.1557 - val_accuracy: 0.6690 - lr: 3.9063e-06
# Epoch 99/100
# 626/626 [==============================] - 46s 74ms/step - loss: 1.0006 - accuracy: 0.7657 - val_loss: 1.1659 - val_accuracy: 0.6688 - lr: 3.9063e-06
# Epoch 100/100
# 626/626 [==============================] - 46s 73ms/step - loss: 0.9957 - accuracy: 0.7649 - val_loss: 1.1463 - val_accuracy: 0.6752 - lr: 3.9063e-06

# %%
# Plotting functions
def plot_accuracy(history):
    plt.figure(figsize=(8,6))
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_loss(history):
    plt.figure(figsize=(8,6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

plot_accuracy(history)
plot_loss(history)

# Retrieve the final training and validation accuracy and loss
final_train_acc = history.history['accuracy'][-1]
final_val_acc = history.history['val_accuracy'][-1]
final_train_loss = history.history['loss'][-1]
final_val_loss = history.history['val_loss'][-1]

# Print the final training and validation accuracy and loss
print(f"Final Training Accuracy: {final_train_acc:.4f}")
print(f"Final Validation Accuracy: {final_val_acc:.4f}")
print(f"Final Training Loss: {final_train_loss:.4f}")
print(f"Final Validation Loss: {final_val_loss:.4f}")
# Out:
# Final Training Accuracy: 0.7649
# Final Validation Accuracy: 0.6752
# Final Training Loss: 0.9957
# Final Validation Loss: 1.1463

# %%
# Function to create a test data generator for a given directory
def create_test_generator(test_dir):
    test_datagen = ImageDataGenerator(rescale=1./255)
    test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=IMG_SIZE,
        color_mode='rgb',  # Keeping RGB as in your original code
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False
    )
    return test_generator

# Evaluate the model on multiple test sets
def evaluate_test_set(model, test_generator, test_dir, categories):
    # Evaluate
    test_loss, test_acc = model.evaluate(test_generator)
    print(f'\nTest Directory: {test_dir}')
    print(f'Test Accuracy: {test_acc:.4f}, Test Loss: {test_loss:.4f}')

    # Predictions and classification report
    predictions = model.predict(test_generator)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = test_generator.classes
    print(classification_report(true_classes, predicted_classes, target_names=categories))

    # Confusion matrix
    cm = confusion_matrix(true_classes, predicted_classes)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=categories)
    disp.plot(cmap=plt.cm.Blues)
    plt.title(f'Confusion Matrix for {os.path.basename(test_dir)}')
    plt.show()

# Loop through each test directory and evaluate
for test_dir in test_dirs:
    test_generator = create_test_generator(test_dir)
    evaluate_test_set(model, test_generator, test_dir, categories)
# Out:
# Found 5 images belonging to 5 classes.
# 1/1 [==============================] - 0s 105ms/step - loss: 2.3552 - accuracy: 0.2000
#
# Test Directory: C:/Users/Melvin Tang/OneDrive/Codes/I2ML/FINALPRO/archive/testgeli
# Test Accuracy: 0.2000, Test Loss: 2.3552
# 1/1 [==============================] - 0s 352ms/step
#               precision    recall  f1-score   support
#
#        angry       0.00      0.00      0.00         1
#         fear       0.00      0.00      0.00         1
#        happy       0.25      1.00      0.40         1
#      neutral       0.00      0.00      0.00         1
#          sad       0.00      0.00      0.00         1
#
#     accuracy                           0.20         5
#    macro avg       0.05      0.20      0.08         5
# weighted avg       0.05      0.20      0.08         5
# e:\Programs\AnacondaEnvironment\envs\py310MLGPU\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# e:\Programs\AnacondaEnvironment\envs\py310MLGPU\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# e:\Programs\AnacondaEnvironment\envs\py310MLGPU\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Found 5 images belonging to 5 classes.
# 1/1 [==============================] - 0s 63ms/step - loss: 1.6629 - accuracy: 0.4000
#
# Test Directory: C:/Users/Melvin Tang/OneDrive/Codes/I2ML/FINALPRO/archive/testkevin
# Test Accuracy: 0.4000, Test Loss: 1.6629
# 1/1 [==============================] - 0s 57ms/step
#               precision    recall  f1-score   support
#
#        angry       0.00      0.00      0.00         1
#         fear       0.00      0.00      0.00         1
#        happy       0.50      1.00      0.67         1
#      neutral       0.00      0.00      0.00         1
#          sad       1.00      1.00      1.00         1
#
#     accuracy                           0.40         5
#    macro avg       0.30      0.40      0.33         5
# weighted avg       0.30      0.40      0.33         5
# e:\Programs\AnacondaEnvironment\envs\py310MLGPU\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# e:\Programs\AnacondaEnvironment\envs\py310MLGPU\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# e:\Programs\AnacondaEnvironment\envs\py310MLGPU\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Found 6216 images belonging to 5 classes.
# 195/195 [==============================] - 8s 39ms/step - loss: 1.1542 - accuracy: 0.6717
#
# Test Directory: C:/Users/Melvin Tang/OneDrive/Codes/I2ML/FINALPRO/archive/test
# Test Accuracy: 0.6717, Test Loss: 1.1542
# 195/195 [==============================] - 6s 29ms/step
#               precision    recall  f1-score   support
#
#        angry       0.59      0.67      0.62       955
#         fear       0.60      0.53      0.56      1020
#        happy       0.90      0.87      0.88      1771
#      neutral       0.59      0.67      0.63      1225
#          sad       0.57      0.52      0.54      1245
#
#     accuracy                           0.67      6216
#    macro avg       0.65      0.65      0.65      6216
# weighted avg       0.67      0.67      0.67      6216

# %%
# After training your model or loading it
# model.save('C:/Users/LENOVO/Downloads/real-time-emotion-recognition/cnn_trial.h5')  # Save it as .h5 format

# %% [markdown]
# ## Gender Classification Model

# %%
import os
import cv2
import numpy as np
from skimage.feature import hog
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import joblib  # For saving the model

# Directories for male and female images
# male_dir = "C:/Users/kevin/Documents/Gender Detection/archive/Training/male"
# female_dir = "C:/Users/kevin/Documents/Gender Detection/archive/Training/female"
male_dir = "C:/Users/Melvin Tang/OneDrive/Codes/I2ML/FINALPRO/archive/gender/Training/male"
female_dir = "C:/Users/Melvin Tang/OneDrive/Codes/I2ML/FINALPRO/archive/gender/Training/female"

image_paths = []
labels = []

# Max number of images to load from each directory
max_images = 2000

# Load male images (limit to 2000)
print("Loading male images")
male_count = 0
for filename in os.listdir(male_dir):
    if male_count >= max_images:
        break
    if filename.endswith('.jpg') or filename.endswith('.png'):
        image_paths.append(os.path.join(male_dir, filename))
        labels.append(0)  # Male label = 0
        male_count += 1

# Load female images (limit to 2000)
print("Loading female images")
female_count = 0
for filename in os.listdir(female_dir):
    if female_count >= max_images:
        break
    if filename.endswith('.jpg') or filename.endswith('.png'):
        image_paths.append(os.path.join(female_dir, filename))
        labels.append(1)  # Female label = 1
        female_count += 1

labels = np.array(labels)

# Function to preprocess images
def preprocess_image(image_path):
    image = cv2.imread(image_path)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    resized_image = cv2.resize(gray_image, (128, 128))
    return resized_image

# Preprocess all images
print("Pre-process")
processed_images = [preprocess_image(image_path) for image_path in image_paths]

# Function to extract HOG features
def extract_hog_features(image):
    features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
    return features

print("Extracting HOG features")
hog_features = [extract_hog_features(img) for img in processed_images]

# Convert HOG features to numpy array
hog_features = np.array(hog_features)

# Split the data into training and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(hog_features, labels, test_size=0.2, random_state=42)

# Train the SVM classifier
print("Training SVM")
svm = SVC(kernel='linear', C=1)
svm.fit(X_train, y_train)

# Evaluate the model
print("Evaluate Model")
y_pred = svm.predict(X_test)
print(classification_report(y_test, y_pred))

# Save the trained model to a file
print("Saving the model")
joblib.dump(svm, 'gender_classifier_model.pkl')  # Save as .pkl or .joblib
# Out:
# Loading male images
# Loading female images
# Pre-process
# Extracting HOG features
# Training SVM
# Evaluate Model
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.90       422
#            1       0.88      0.91      0.89       378
#
#     accuracy                           0.90       800
#    macro avg       0.89      0.90      0.89       800
# weighted avg       0.90      0.90      0.90       800
#
# Saving the model
# ['gender_classifier_model.pkl']

# %% [markdown]
# ## Export Models

# %%
# Save both models as .h5 files
model.save("emotion_model.h5")
print("Emotion model saved as emotion_model.h5")

#gender_model.save("gender_model.h5")
#print("Gender model saved as gender_model.h5")
# Out:
# Emotion model saved as emotion_model.h5
